# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from statistics import mode

from IPython.display import Image
sns.set(style="darkgrid")

# %%
# load data
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# modelling
import statsmodels.formula.api as smf

# %%
#import dataset from csv file
df = pd.read_csv('disnakertrans-od_19869_jml_pengangguran_terbuka__pendidikan_kabupatenkota_data.csv')
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2   3             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3   4             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 4   5             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
#
#     pendidikan  jumlah_pengangguran satuan  tahun
# 0  SD KE BAWAH                90529  ORANG   2011
# 1         SLTP                38379  ORANG   2011
# 2         SLTA                93730  ORANG   2011
# 3  SD KE BAWAH                33242  ORANG   2011
# 4         SLTP                28191  ORANG   2011

# %%
# checking missing value
df.isnull().sum()
# Out:
# id                     0
# kode_provinsi          0
# nama_provinsi          0
# kode_kabupaten_kota    0
# nama_kabupaten_kota    0
# pendidikan             0
# jumlah_pengangguran    0
# satuan                 0
# tahun                  0
# dtype: int64

# %%
# information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1431 entries, 0 to 1430
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1431 non-null   int64
#  1   kode_provinsi        1431 non-null   int64
#  2   nama_provinsi        1431 non-null   object
#  3   kode_kabupaten_kota  1431 non-null   int64
#  4   nama_kabupaten_kota  1431 non-null   object
#  5   pendidikan           1431 non-null   object
#  6   jumlah_pengangguran  1431 non-null   int64
#  7   satuan               1431 non-null   object
#  8   tahun                1431 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 100.7+ KB

# %%
df.loc[df['jumlah_pengangguran']==max(df['jumlah_pengangguran'])]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 759  760             32    JAWA BARAT                 3201
#
#     nama_kabupaten_kota pendidikan  jumlah_pengangguran satuan  tahun
# 759     KABUPATEN BOGOR        SMA               136782  ORANG   2018

# %%
df.loc[df['jumlah_pengangguran']==min(df['jumlah_pengangguran'])]
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 51      52             32    JAWA BARAT                 3218
# 52      53             32    JAWA BARAT                 3218
# 53      54             32    JAWA BARAT                 3218
# 105    106             32    JAWA BARAT                 3205
# 111    112             32    JAWA BARAT                 3207
# 150    151             32    JAWA BARAT                 3214
# 155    156             32    JAWA BARAT                 3215
# 166    167             32    JAWA BARAT                 3218
# 167    168             32    JAWA BARAT                 3218
# 168    169             32    JAWA BARAT                 3218
# 169    170             32    JAWA BARAT                 3218
# 170    171             32    JAWA BARAT                 3218
# 280    281             32    JAWA BARAT                 3213
# 290    291             32    JAWA BARAT                 3215
# ...

# %%
sns.histplot(data=df, x = 'jumlah_pengangguran', bins=40)
plt.show()

# %%
df[['jumlah_pengangguran','tahun']].corr()
# Out:
#                      jumlah_pengangguran     tahun
# jumlah_pengangguran             1.000000  0.016812
# tahun                           0.016812  1.000000

# %%
sns.countplot(x = df["tahun"], color="blue").set(title='Jumlah Pengangguran per tahun')
# Out:
# [Text(0.5, 1.0, 'Jumlah Pengangguran per tahun')]

# %%
plt.figure(figsize = (10,6))
plt.plot(df['tahun'], df['pendidikan'], marker = 's',alpha = 0.8)
plt.xlabel('tahun')
plt.ylabel('pendidikan')
plt.title('Total pengangguran berdasarkan pendidikan')
plt.show()

# %%
dfProduct = df.groupby('pendidikan')[["jumlah_pengangguran"]].sum().sort_values(by = "jumlah_pengangguran", ascending = False)
dfProduct = dfProduct.reset_index()
dfProduct.head(10)
# Out:
#                                         pendidikan  jumlah_pengangguran
# 0                                              SMA              5690129
# 1                                              SMP              4227574
# 2                                               SD              2630333
# 3                                      SD KE BAWAH              2025451
# 4                                   SMA (KEJURUAN)              1928083
# 5                                       SMA (UMUM)              1727194
# 6             DIPLOMA I/II/III/AKADEMI/UNIVERSITAS              1590724
# 7  TIDAK/BELUM PERNAH SEKOLAH/TIDAK/BELUM TAMAT SD               777337
# 8                                             SLTA               776639
# 9                                             SLTP               494091

# %%
dfProduct = df.groupby('tahun')[["jumlah_pengangguran"]].sum().sort_values(by = "tahun", ascending = False)
dfProduct = dfProduct.reset_index()
dfProduct.head(10)
# Out:
#    tahun  jumlah_pengangguran
# 0   2022              2125606
# 1   2021              2430147
# 2   2020              2533076
# 3   2019              1901498
# 4   2018              1848234
# 5   2017              1839428
# 6   2015              1794874
# 7   2014              1775196
# 8   2013              1888667
# 9   2012              1828986

# %%
df.loc[df['jumlah_pengangguran']==min(df['jumlah_pengangguran'])].describe()
# Out:
#                 id  kode_provinsi  kode_kabupaten_kota  jumlah_pengangguran  \
# count    55.000000           55.0            55.000000                 55.0
# mean    514.872727           32.0          3220.200000                  0.0
# std     342.376555            0.0            22.263074                  0.0
# min      52.000000           32.0          3202.000000                  0.0
# 25%     296.500000           32.0          3207.000000                  0.0
# 50%     439.000000           32.0          3215.000000                  0.0
# 75%     654.000000           32.0          3218.000000                  0.0
# max    1417.000000           32.0          3279.000000                  0.0
#
#              tahun
# count    55.000000
# mean   2015.054545
# std       3.033261
# min    2011.000000
# 25%    2013.000000
# 50%    2014.000000
# 75%    2017.000000
# max    2022.000000

# %%
#get histogram and scatterplot between numeric variables
sns.pairplot(df)
plt.show()

# %%
# Get correlation between numeric variables
df[["jumlah_pengangguran","tahun"]].corr()
# Out:
#                      jumlah_pengangguran     tahun
# jumlah_pengangguran             1.000000  0.016812
# tahun                           0.016812  1.000000

# %%
df_as = df.groupby("tahun")["jumlah_pengangguran"].mean()
df_as.plot()
plt.ylabel("AVG of jumlah pengangguran")
plt.show()

# %%
sns.countplot(x ='tahun', data = df)
plt.show()

# %%
col = ['id', 'kode_provinsi', 'nama_provinsi', 'kode_kabupaten_kota',
       'nama_kabupaten_kota', 'pendidikan', 'jumlah_pengangguran',
       'satuan', 'tahun']

# %%
plt.figure(figsize=(12, 10))

heatmap = sns.heatmap(df[col].corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
import matplotlib.pyplot as plt

x = df["tahun"]
y = df["jumlah_pengangguran"]

# Plot the data
plt.scatter(x, y, color = "k", marker=".")

# Add a legend and labels

plt.xlabel("tahun")
plt.ylabel("jumlah_pengangguran")

# Add a title and adjust the margins
plt.title("Data")

# Show the plot
plt.show()
